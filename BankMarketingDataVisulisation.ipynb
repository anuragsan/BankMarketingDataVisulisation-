# %%
import pandas as pd

# %%
BankData = 'Bank.csv'

# %%
BankDataShow = pd.read_csv(BankData,sep =';',decimal ='.',header=None,names=['age','job','marital','education','default','housing','loan','contact','month','day_of_week','duration','campaign','pdays','previous','poutcome','emp.var.rate','cons.price.idx','cons.conf.idx','euribor3m','nr.employed','y'])

# %%
BankDataShow.head(5)
# Out:
#    age          job  marital    education  default  housing     loan  \
# 0  age          job  marital    education  default  housing     loan
# 1   30  blue-collar  married     basic.9y       no      yes       no
# 2   39     services   single  high.school       no       no       no
# 3   25     services  married  high.school       no      yes       no
# 4   38     services  married     basic.9y       no  unknown  unknown
#
#      contact  month  day_of_week ...  campaign  pdays  previous     poutcome  \
# 0    contact  month  day_of_week ...  campaign  pdays  previous     poutcome
# 1   cellular    may          fri ...         2    999         0  nonexistent
# 2  telephone    may          fri ...         4    999         0  nonexistent
# 3  telephone    jun          wed ...         1    999         0  nonexistent
# 4  telephone    jun          fri ...         3    999         0  nonexistent
#
#    emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %%
BankDataShow=BankDataShow.drop([0])

# %%
BankDataShow.head(5)
# Out:
#   age          job  marital          education default  housing     loan  \
# 1  30  blue-collar  married           basic.9y      no      yes       no
# 2  39     services   single        high.school      no       no       no
# 3  25     services  married        high.school      no      yes       no
# 4  38     services  married           basic.9y      no  unknown  unknown
# 5  47       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week ... campaign pdays previous     poutcome  \
# 1   cellular   may         fri ...        2   999        0  nonexistent
# 2  telephone   may         fri ...        4   999        0  nonexistent
# 3  telephone   jun         wed ...        1   999        0  nonexistent
# 4  telephone   jun         fri ...        3   999        0  nonexistent
# 5   cellular   nov         mon ...        1   999        0  nonexistent
#
#   emp.var.rate cons.price.idx cons.conf.idx euribor3m nr.employed   y
# ...

# %%
BankDataShow.dtypes
# Out:
# age               object
# job               object
# marital           object
# education         object
# default           object
# housing           object
# loan              object
# contact           object
# month             object
# day_of_week       object
# duration          object
# campaign          object
# pdays             object
# previous          object
# poutcome          object
# emp.var.rate      object
# cons.price.idx    object
# cons.conf.idx     object
# euribor3m         object
# nr.employed       object
# y                 object
# dtype: object

# %%
BankDataShow.describe()
# Out:
#          age     job  marital          education default housing  loan  \
# count   4116    4119     4119               4119    4119    4119  4119
# unique    69      12        5                 10       5       4     5
# top       32  admin.  married  university.degree      no     yes    no
# freq     216    1012     2509               1264    3312    2173  3348
#
#          contact month day_of_week  ...  campaign pdays previous     poutcome  \
# count       4119  4119        4119  ...      4119  4119     4119         4119
# unique         5    13           9  ...        28    23       10            7
# top     cellular   may         thu  ...         1   999        0  nonexistent
# freq        2649  1377         858  ...      1762  3955     3519         3519
#
#        emp.var.rate cons.price.idx cons.conf.idx euribor3m nr.employed     y
# count          4119           4115          4118      4116        4115  4115
# ...

# %%
BankDataShow[['age','duration','campaign','pdays','previous','emp.var.rate','cons.price.idx','cons.conf.idx','euribor3m','nr.employed']]=BankDataShow[['age','duration','campaign','pdays','previous','emp.var.rate','cons.price.idx','cons.conf.idx','euribor3m','nr.employed']].apply(pd.to_numeric,errors='coerce')

# %%
BankDataShow.dtypes
# Out:
# age               float64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration          float64
# campaign          float64
# pdays             float64
# previous          float64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %%
BankDataShow.info
# Out:
# <bound method DataFrame.info of        age            job   marital            education  default  housing  \
# 1     30.0    blue-collar   married             basic.9y       no      yes
# 2     39.0       services    single          high.school       no       no
# 3     25.0       services   married          high.school       no      yes
# 4     38.0       services   married             basic.9y       no  unknown
# 5     47.0         admin.   married    university.degree       no      yes
# 6     32.0       services    single    university.degree       no       no
# 7     32.0         admin.    single    university.degree       no      yes
# 8     41.0   entrepreneur   married    university.degree  unknown      yes
# 9     31.0       services  divorced  professional.course       no       no
# 10    35.0    blue-collar   married             basic.9y  unknown       no
# 11    25.0       services    single             basic.6y  unknown      yes
# ...

# %%
BankDataShow.age.value_counts()
# Out:
# 32.0     216
# 31.0     191
# 30.0     177
# 34.0     174
# 35.0     172
# 33.0     170
# 36.0     166
# 38.0     150
# 41.0     147
# 29.0     139
# 37.0     137
# 39.0     133
# 42.0     112
# 28.0     108
# 43.0     107
# 47.0     107
# 45.0     104
# 40.0     102
# 46.0      99
# 44.0      97
# 54.0      88
# 27.0      87
# 48.0      86
# 49.0      85
# 50.0      84
# 53.0      78
# 51.0      77
# 52.0      77
# 56.0      75
# 55.0      68
#         ...
# 21.0       7
# 61.0       7
# 66.0       6
# 71.0       5
# 62.0       5
# 64.0       5
# 67.0       4
# 68.0       4
# 80.0       4
# 76.0       4
# 63.0       4
# 20.0       4
# 78.0       3
# 18.0       3
# 81.0       3
# 74.0       3
# 73.0       3
# 65.0       3
# 82.0       2
# 70.0       2
# 75.0       2
# 86.0       2
# 69.0       2
# 72.0       2
# 77.0       2
# 88.0       1
# 143.0      1
# 85.0       1
# 19.0       1
# 250.0      1
# Name: age, Length: 69, dtype: int64

# %%
BankDataShow_Age_Outlier=BankDataShow[ BankDataShow['age'] > 135]

# %%
BankDataShow_Age_Outlier.head(5)
# Out:
#        age         job  marital education default housing loan   contact  \
# 386  143.0  unemployed  married  basic.4y      no      no   no  cellular
# 395  250.0      admin.  married  basic.9y      no      no   no  cellular
#
#     month day_of_week ...  campaign  pdays  previous     poutcome  \
# 386   may         wed ...       2.0  999.0       0.0  nonexistent
# 395   aug         thu ...       1.0  999.0       0.0  nonexistent
#
#     emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 386         -1.8          92.893          -46.2      1.334       5099.1  no
# 395          1.4          93.444          -36.1      4.968       5228.1  no
#
# [2 rows x 21 columns]

# %%
BankDataShow = BankDataShow.drop(BankDataShow_Age_Outlier.index,axis=0)

# %%
BankDataShow_Age_Outlier=BankDataShow[ BankDataShow['age'] > 135 ]

# %%
BankDataShow_Age_Outlier
# Out:
# Empty DataFrame
# Columns: [age, job, marital, education, default, housing, loan, contact, month, day_of_week, duration, campaign, pdays, previous, poutcome, emp.var.rate, cons.price.idx, cons.conf.idx, euribor3m, nr.employed, y]
# Index: []
#
# [0 rows x 21 columns]

# %%
BankDataShow['age'].value_counts()
# Out:
# 32.0    216
# 31.0    191
# 30.0    177
# 34.0    174
# 35.0    172
# 33.0    170
# 36.0    166
# 38.0    150
# 41.0    147
# 29.0    139
# 37.0    137
# 39.0    133
# 42.0    112
# 28.0    108
# 47.0    107
# 43.0    107
# 45.0    104
# 40.0    102
# 46.0     99
# 44.0     97
# 54.0     88
# 27.0     87
# 48.0     86
# 49.0     85
# 50.0     84
# 53.0     78
# 51.0     77
# 52.0     77
# 56.0     75
# 55.0     68
#        ...
# 23.0     16
# 22.0     10
# 21.0      7
# 61.0      7
# 66.0      6
# 62.0      5
# 64.0      5
# 71.0      5
# 76.0      4
# 68.0      4
# 20.0      4
# 63.0      4
# 67.0      4
# 80.0      4
# 78.0      3
# 18.0      3
# 81.0      3
# 73.0      3
# 65.0      3
# 74.0      3
# 72.0      2
# 86.0      2
# 82.0      2
# 75.0      2
# 69.0      2
# 77.0      2
# 70.0      2
# 88.0      1
# 19.0      1
# 85.0      1
# Name: age, Length: 67, dtype: int64

# %%
BankDataShow['job'].value_counts()
# Out:
# admin.           1011
# blue-collar       884
# technician        691
# services          393
# management        324
# retired           166
# self-employed     159
# entrepreneur      148
# housemaid         110
# unemployed        110
# student            82
# unknown            39
# Name: job, dtype: int64

# %%
BankDataShow['job'] = BankDataShow['job'].str.replace('admin.','admin')

# %%
BankDataShow['job'].value_counts()
# Out:
# admin            1011
# blue-collar       884
# technician        691
# services          393
# management        324
# retired           166
# self-employed     159
# entrepreneur      148
# housemaid         110
# unemployed        110
# student            82
# unknown            39
# Name: job, dtype: int64

# %%
BankDataShow['marital'].value_counts()
# Out:
# married                  2507
# single                   1153
# divorced                  445
# unknown                    11
# divorceded”;”basic.9y       1
# Name: marital, dtype: int64

# %%
BankDataShow[BankDataShow["marital"].isin(["married", "single", "divorced", "unknown"]) == False].index
# Out:
# Int64Index([651], dtype='int64')

# %%
BankDataShow=BankDataShow.drop([651])

# %%
BankDataShow[BankDataShow["marital"].isin(["married", "single", "divorced", "unknown"]) == False].index
# Out:
# Int64Index([], dtype='int64')

# %%
BankDataShow['education'].value_counts()
# Out:
# university.degree      1264
# high.school             921
# basic.9y                572
# professional.course     535
# basic.4y                428
# basic.6y                227
# unknown                 167
# illiterate                1
# basic.6yes”;”no           1
# Name: education, dtype: int64

# %%
BankDataShow[BankDataShow["education"].isin(["basic.6yes”;”no"]) == True].index
# Out:
# Int64Index([575], dtype='int64')

# %%
BankDataShow=BankDataShow.drop([575])

# %%
BankDataShow[BankDataShow["education"].isin(["basic.6yes”;”no"]) == True].index
# Out:
# Int64Index([], dtype='int64')

# %%
BankDataShow['default'].value_counts()
# Out:
# no           3310
# unknown       803
# noo”;”yes       1
# yes             1
# Name: default, dtype: int64

# %%
BankDataShow[BankDataShow["default"].isin(["noo”;”yes"]) == True].index
# Out:
# Int64Index([570], dtype='int64')

# %%
BankDataShow=BankDataShow.drop([570])

# %%
BankDataShow[BankDataShow["default"].isin(["noo”;”yes"]) == True].index
# Out:
# Int64Index([], dtype='int64')

# %%
BankDataShow['housing'].value_counts()
# Out:
# yes        2172
# no         1837
# unknown     105
# Name: housing, dtype: int64

# %%
BankDataShow['loan'].value_counts()
# Out:
# no         3346
# yes         663
# unknown     105
# Name: loan, dtype: int64

# %%
BankDataShow['contact'].value_counts()
# Out:
# cellular     2647
# telephone    1467
# Name: contact, dtype: int64

# %%
BankDataShow['month'].value_counts()
# Out:
# may    1376
# jul     710
# aug     634
# jun     530
# nov     446
# apr     215
# oct      69
# sep      64
# mar      48
# dec      22
# Name: month, dtype: int64

# %%
BankDataShow['day_of_week'].value_counts()
# Out:
# thu                            857
# mon                            854
# tue                            840
# wed                            794
# fri                            768
# thu”;-;1;999;0;nonexistent"      1
# Name: day_of_week, dtype: int64

# %%
BankDataShow[BankDataShow["day_of_week"].isin(["mon","tue","wed","thu","fri","sat","sun"]) == False].index
# Out:
# Int64Index([679], dtype='int64')

# %%
BankDataShow=BankDataShow.drop([679])

# %%
BankDataShow['day_of_week'].value_counts()
# Out:
# thu    857
# mon    854
# tue    840
# wed    794
# fri    768
# Name: day_of_week, dtype: int64

# %%
BankDataShow['duration'].value_counts()
# Out:
# 77.0      24
# 112.0     23
# 73.0      22
# 81.0      21
# 90.0      20
# 145.0     20
# 83.0      20
# 122.0     20
# 113.0     20
# 114.0     19
# 88.0      19
# 131.0     19
# 135.0     19
# 159.0     18
# 103.0     18
# 87.0      18
# 107.0     18
# 155.0     18
# 69.0      17
# 139.0     17
# 95.0      17
# 161.0     17
# 204.0     17
# 147.0     17
# 111.0     17
# 180.0     17
# 130.0     17
# 160.0     17
# 181.0     16
# 164.0     16
#           ..
# 726.0      1
# 687.0      1
# 515.0      1
# 771.0      1
# 800.0      1
# 1009.0     1
# 1186.0     1
# 1806.0     1
# 757.0      1
# 1207.0     1
# 1300.0     1
# 892.0      1
# 646.0      1
# 716.0      1
# 1720.0     1
# 1128.0     1
# 823.0      1
# 1190.0     1
# 992.0      1
# 611.0      1
# 825.0      1
# 898.0      1
# 638.0      1
# 373.0      1
# 371.0      1
# 1365.0     1
# 637.0      1
# 1590.0     1
# 449.0      1
# 457.0      1
# Name: duration, Length: 828, dtype: int64

# %%
BankDataShow['campaign'].value_counts()
# Out:
# 1.0     1761
# 2.0     1038
# 3.0      548
# 4.0      291
# 5.0      142
# 6.0       98
# 7.0       60
# 8.0       36
# 9.0       32
# 10.0      20
# 11.0      19
# 12.0      16
# 17.0      14
# 13.0      11
# 16.0       7
# 14.0       6
# 29.0       2
# 15.0       2
# 22.0       2
# 19.0       2
# 23.0       2
# 18.0       1
# 24.0       1
# 27.0       1
# 35.0       1
# Name: campaign, dtype: int64

# %%
BankDataShow['pdays'].value_counts()
# Out:
# 999.0    3953
# 3.0        52
# 6.0        42
# 4.0        14
# 7.0        10
# 10.0        8
# 12.0        5
# 5.0         4
# 2.0         4
# 1.0         3
# 9.0         3
# 18.0        2
# 13.0        2
# 15.0        2
# 0.0         2
# 16.0        2
# 21.0        1
# 11.0        1
# 19.0        1
# 17.0        1
# 14.0        1
# Name: pdays, dtype: int64

# %%
BankDataShow['previous'].value_counts()
# Out:
# 0.0    3517
# 1.0     475
# 2.0      78
# 3.0      25
# 4.0      14
# 6.0       2
# 5.0       2
# Name: previous, dtype: int64

# %%
BankDataShow['poutcome'].value_counts()
# Out:
# nonexistent    3517
# failure         454
# success         142
# Name: poutcome, dtype: int64

# %%
BankDataShow['emp.var.rate'].value_counts()
# Out:
#  1.4    1623
# -1.8     881
#  1.1     757
# -0.1     392
# -2.9     164
# -3.4     104
# -1.7      87
# -1.1      83
# -3.0      21
# -0.2       1
# Name: emp.var.rate, dtype: int64

# %%
BankDataShow['cons.price.idx'].value_counts()
# Out:
# 93.994    755
# 93.918    665
# 92.893    595
# 93.444    526
# 94.465    431
# 93.200    386
# 93.075    201
# 92.201     75
# 92.963     75
# 92.431     43
# 94.199     39
# 92.649     36
# 94.027     33
# 94.215     30
# 92.379     25
# 92.843     25
# 94.767     24
# 94.055     24
# 93.876     23
# 93.369     23
# 92.713     21
# 94.601     20
# 93.749     14
# 92.469     14
# 93.798      6
# 92.756      1
# Name: cons.price.idx, dtype: int64

# %%
BankDataShow['cons.conf.idx'].value_counts()
# Out:
# -36.4    757
# -42.7    666
# -46.2    595
# -36.1    526
# -41.8    431
# -42.0    386
# -47.1    201
# -31.4     75
# -40.8     75
# -26.9     43
# -37.5     39
# -30.1     36
# -38.3     33
# -40.3     30
# -50.0     25
# -29.8     25
# -50.8     24
# -39.8     24
# -34.8     23
# -40.0     23
# -33.0     21
# -49.5     20
# -33.6     14
# -34.6     14
# -40.4      6
# -45.9      1
# Name: cons.conf.idx, dtype: int64

# %%
BankDataShow['euribor3m'].value_counts()
# Out:
# 4.857    274
# 4.963    255
# 4.962    236
# 4.961    212
# 4.856    138
# 4.965    114
# 4.964    110
# 1.405    106
# 4.960    105
# 4.076    100
# 4.968    100
# 4.864     97
# 4.120     82
# 4.855     81
# 4.860     80
# 4.859     76
# 4.959     76
# 4.191     73
# 4.966     72
# 1.266     71
# 1.281     68
# 4.858     66
# 4.958     66
# 4.153     64
# 4.967     62
# 4.021     61
# 1.299     59
# 1.327     58
# 1.334     57
# 1.250     54
#         ...
# 1.520      1
# 0.721      1
# 4.245      1
# 1.687      1
# 1.531      1
# 4.663      1
# 0.937      1
# 0.672      1
# 0.829      1
# 0.640      1
# 1.044      1
# 1.602      1
# 0.709      1
# 0.755      1
# 0.996      1
# 0.885      1
# 1.043      1
# 0.752      1
# 0.778      1
# 3.853      1
# 0.707      1
# 4.592      1
# 0.965      1
# 1.085      1
# 1.538      1
# 1.046      1
# 0.710      1
# 0.650      1
# 1.778      1
# 1.224      1
# Name: euribor3m, Length: 234, dtype: int64

# %%
BankDataShow['nr.employed'].value_counts()
# Out:
# 5228.1    1623
# 5099.1     820
# 5191.0     757
# 5195.8     392
# 5076.2     164
# 5017.5     104
# 4991.6      87
# 4963.6      83
# 5008.7      59
# 5023.5      21
# 5176.3       1
# Name: nr.employed, dtype: int64

# %%
BankDataShow['y'].value_counts()
# Out:
# no     3662
# yes     451
# Name: y, dtype: int64

# %%
BankDataShow.head(5)
# Out:
#     age          job  marital          education default  housing     loan  \
# 1  30.0  blue-collar  married           basic.9y      no      yes       no
# 2  39.0     services   single        high.school      no       no       no
# 3  25.0     services  married        high.school      no      yes       no
# 4  38.0     services  married           basic.9y      no  unknown  unknown
# 5  47.0        admin  married  university.degree      no      yes       no
#
#      contact month day_of_week ...  campaign  pdays  previous     poutcome  \
# 1   cellular   may         fri ...       2.0  999.0       0.0  nonexistent
# 2  telephone   may         fri ...       4.0  999.0       0.0  nonexistent
# 3  telephone   jun         wed ...       1.0  999.0       0.0  nonexistent
# 4  telephone   jun         fri ...       3.0  999.0       0.0  nonexistent
# 5   cellular   nov         mon ...       1.0  999.0       0.0  nonexistent
#
# ...

# %%
BankDataShow['job'].str.strip()
# Out:
# 1         blue-collar
# 2            services
# 3            services
# 4            services
# 5               admin
# 6            services
# 7               admin
# 8        entrepreneur
# 9            services
# 10        blue-collar
# 11           services
# 12      self-employed
# 13              admin
# 14        blue-collar
# 15              admin
# 16           services
# 17              admin
# 18              admin
# 19       entrepreneur
# 20        blue-collar
# 21           services
# 22         technician
# 23         technician
# 24         management
# 25         technician
# 26         technician
# 27         technician
# 28        blue-collar
# 29              admin
# 30              admin
#             ...
# 4090            admin
# 4091      blue-collar
# 4092       management
# 4093      blue-collar
# 4094          retired
# 4095      blue-collar
# 4096            admin
# 4097         services
# 4098      blue-collar
# 4099        housemaid
# ...

# %%
BankDataShow.head(5)
# Out:
#     age          job  marital          education default  housing     loan  \
# 1  30.0  blue-collar  married           basic.9y      no      yes       no
# 2  39.0     services   single        high.school      no       no       no
# 3  25.0     services  married        high.school      no      yes       no
# 4  38.0     services  married           basic.9y      no  unknown  unknown
# 5  47.0        admin  married  university.degree      no      yes       no
#
#      contact month day_of_week ...  campaign  pdays  previous     poutcome  \
# 1   cellular   may         fri ...       2.0  999.0       0.0  nonexistent
# 2  telephone   may         fri ...       4.0  999.0       0.0  nonexistent
# 3  telephone   jun         wed ...       1.0  999.0       0.0  nonexistent
# 4  telephone   jun         fri ...       3.0  999.0       0.0  nonexistent
# 5   cellular   nov         mon ...       1.0  999.0       0.0  nonexistent
#
# ...

# %%
BankDataShow['marital'].str.strip()
# Out:
# 1        married
# 2         single
# 3        married
# 4        married
# 5        married
# 6         single
# 7         single
# 8        married
# 9       divorced
# 10       married
# 11        single
# 12        single
# 13       married
# 14       married
# 15        single
# 16        single
# 17      divorced
# 18      divorced
# 19       married
# 20       married
# 21       married
# 22      divorced
# 23        single
# 24       married
# 25       married
# 26       married
# 27      divorced
# 28       married
# 29        single
# 30       married
#           ...
# 4090      single
# 4091     married
# 4092     married
# 4093      single
# 4094     married
# 4095     married
# 4096      single
# 4097     married
# 4098    divorced
# 4099      single
# 4100    divorced
# 4101    divorced
# 4102      single
# 4103      single
# 4104     married
# 4105    divorced
# 4106     married
# 4107    divorced
# 4108     married
# 4109     married
# 4110     married
# ...

# %%
BankDataShow['education'].str.strip()
# Out:
# 1                  basic.9y
# 2               high.school
# 3               high.school
# 4                  basic.9y
# 5         university.degree
# 6         university.degree
# 7         university.degree
# 8         university.degree
# 9       professional.course
# 10                 basic.9y
# 11                 basic.6y
# 12                 basic.4y
# 13              high.school
# 14                 basic.4y
# 15              high.school
# 16        university.degree
# 17        university.degree
# 18        university.degree
# 19        university.degree
# 20                 basic.4y
# 21                 basic.6y
# 22              high.school
# 23        university.degree
# 24              high.school
# 25      professional.course
# 26      professional.course
# 27      professional.course
# 28                 basic.6y
# 29                  unknown
# 30        university.degree
#                ...
# 4090      university.degree
# 4091               basic.4y
# ...

# %%
BankDataShow['default'].str.strip()
# Out:
# 1            no
# 2            no
# 3            no
# 4            no
# 5            no
# 6            no
# 7            no
# 8       unknown
# 9            no
# 10      unknown
# 11      unknown
# 12           no
# 13           no
# 14           no
# 15           no
# 16           no
# 17           no
# 18           no
# 19      unknown
# 20           no
# 21      unknown
# 22           no
# 23           no
# 24           no
# 25      unknown
# 26           no
# 27           no
# 28      unknown
# 29      unknown
# 30           no
#          ...
# 4090         no
# 4091    unknown
# 4092    unknown
# 4093         no
# 4094    unknown
# 4095         no
# 4096         no
# 4097         no
# 4098         no
# 4099         no
# 4100         no
# 4101         no
# 4102         no
# 4103    unknown
# 4104         no
# 4105         no
# 4106    unknown
# 4107         no
# 4108    unknown
# 4109         no
# 4110         no
# 4111    unknown
# 4112         no
# 4113         no
# ...

# %%
BankDataShow['housing'].str.strip()
# Out:
# 1           yes
# 2            no
# 3           yes
# 4       unknown
# 5           yes
# 6            no
# 7           yes
# 8           yes
# 9            no
# 10           no
# 11          yes
# 12           no
# 13           no
# 14          yes
# 15           no
# 16           no
# 17           no
# 18          yes
# 19          yes
# 20           no
# 21          yes
# 22           no
# 23          yes
# 24           no
# 25          yes
# 26          yes
# 27           no
# 28           no
# 29           no
# 30           no
#          ...
# 4090        yes
# 4091        yes
# 4092         no
# 4093         no
# 4094         no
# 4095        yes
# 4096         no
# 4097         no
# 4098         no
# 4099        yes
# 4100         no
# 4101         no
# 4102        yes
# 4103         no
# 4104         no
# 4105        yes
# 4106        yes
# 4107        yes
# 4108        yes
# 4109        yes
# 4110         no
# 4111    unknown
# 4112         no
# 4113        yes
# ...

# %%
BankDataShow['loan'].str.strip()
# Out:
# 1            no
# 2            no
# 3            no
# 4       unknown
# 5            no
# 6            no
# 7            no
# 8            no
# 9            no
# 10           no
# 11           no
# 12           no
# 13           no
# 14           no
# 15           no
# 16           no
# 17           no
# 18           no
# 19          yes
# 20          yes
# 21           no
# 22           no
# 23          yes
# 24          yes
# 25           no
# 26           no
# 27           no
# 28           no
# 29           no
# 30           no
#          ...
# 4090        yes
# 4091        yes
# 4092         no
# 4093         no
# 4094         no
# 4095         no
# 4096        yes
# 4097         no
# 4098         no
# 4099         no
# 4100         no
# 4101         no
# 4102         no
# 4103        yes
# 4104         no
# 4105         no
# 4106         no
# 4107         no
# 4108         no
# 4109         no
# 4110         no
# 4111    unknown
# 4112        yes
# 4113         no
# ...

# %%
BankDataShow['contact'].str.strip()
# Out:
# 1        cellular
# 2       telephone
# 3       telephone
# 4       telephone
# 5        cellular
# 6        cellular
# 7        cellular
# 8        cellular
# 9        cellular
# 10      telephone
# 11       cellular
# 12       cellular
# 13      telephone
# 14      telephone
# 15       cellular
# 16       cellular
# 17       cellular
# 18      telephone
# 19       cellular
# 20       cellular
# 21       cellular
# 22       cellular
# 23       cellular
# 24       cellular
# 25      telephone
# 26       cellular
# 27      telephone
# 28       cellular
# 29      telephone
# 30       cellular
#           ...
# 4090     cellular
# 4091    telephone
# 4092    telephone
# 4093    telephone
# 4094     cellular
# 4095     cellular
# 4096     cellular
# 4097    telephone
# 4098     cellular
# 4099     cellular
# 4100     cellular
# 4101     cellular
# 4102     cellular
# 4103    telephone
# 4104    telephone
# 4105     cellular
# 4106    telephone
# 4107     cellular
# 4108     cellular
# ...

# %%
BankDataShow['month'].str.strip()
# Out:
# 1       may
# 2       may
# 3       jun
# 4       jun
# 5       nov
# 6       sep
# 7       sep
# 8       nov
# 9       nov
# 10      may
# 11      jul
# 12      jul
# 13      may
# 14      jun
# 15      may
# 16      jul
# 17      jul
# 18      jul
# 19      aug
# 20      jul
# 21      jul
# 22      mar
# 23      aug
# 24      aug
# 25      may
# 26      aug
# 27      may
# 28      may
# 29      may
# 30      aug
#        ...
# 4090    oct
# 4091    may
# 4092    may
# 4093    jul
# 4094    jul
# 4095    nov
# 4096    aug
# 4097    may
# 4098    aug
# 4099    aug
# 4100    aug
# 4101    apr
# 4102    jul
# 4103    jun
# 4104    may
# 4105    aug
# 4106    jul
# 4107    may
# 4108    aug
# 4109    may
# 4110    oct
# 4111    may
# 4112    jun
# 4113    nov
# 4114    nov
# 4115    jul
# 4116    jul
# 4117    may
# 4118    aug
# 4119    nov
# Name: month, Length: 4113, dtype: object

# %%
BankDataShow['day_of_week'].str.strip()
# Out:
# 1       fri
# 2       fri
# 3       wed
# 4       fri
# 5       mon
# 6       thu
# 7       mon
# 8       mon
# 9       tue
# 10      thu
# 11      thu
# 12      thu
# 13      wed
# 14      thu
# 15      fri
# 16      wed
# 17      wed
# 18      mon
# 19      mon
# 20      tue
# 21      tue
# 22      mon
# 23      wed
# 24      wed
# 25      fri
# 26      mon
# 27      wed
# 28      mon
# 29      thu
# 30      tue
#        ...
# 4090    fri
# 4091    tue
# 4092    thu
# 4093    wed
# 4094    tue
# 4095    mon
# 4096    fri
# 4097    mon
# 4098    tue
# 4099    thu
# 4100    tue
# 4101    fri
# 4102    mon
# 4103    fri
# 4104    mon
# 4105    mon
# 4106    tue
# 4107    tue
# 4108    wed
# 4109    thu
# 4110    wed
# 4111    fri
# 4112    fri
# 4113    thu
# 4114    thu
# 4115    thu
# 4116    fri
# 4117    mon
# 4118    fri
# 4119    wed
# Name: day_of_week, Length: 4113, dtype: object

# %%
BankDataShow['poutcome'].str.strip()
# Out:
# 1       nonexistent
# 2       nonexistent
# 3       nonexistent
# 4       nonexistent
# 5       nonexistent
# 6           failure
# 7       nonexistent
# 8       nonexistent
# 9           failure
# 10      nonexistent
# 11      nonexistent
# 12      nonexistent
# 13      nonexistent
# 14      nonexistent
# 15      nonexistent
# 16      nonexistent
# 17      nonexistent
# 18      nonexistent
# 19      nonexistent
# 20      nonexistent
# 21      nonexistent
# 22          success
# 23      nonexistent
# 24      nonexistent
# 25      nonexistent
# 26      nonexistent
# 27      nonexistent
# 28          failure
# 29      nonexistent
# 30      nonexistent
#            ...
# 4090        failure
# 4091    nonexistent
# 4092    nonexistent
# 4093    nonexistent
# 4094    nonexistent
# 4095        success
# 4096    nonexistent
# 4097    nonexistent
# 4098    nonexistent
# 4099    nonexistent
# 4100    nonexistent
# 4101    nonexistent
# 4102    nonexistent
# 4103    nonexistent
# ...

# %%
BankDataShow['y'].str.strip()
# Out:
# 1        no
# 2        no
# 3        no
# 4        no
# 5        no
# 6        no
# 7        no
# 8        no
# 9        no
# 10       no
# 11       no
# 12       no
# 13       no
# 14       no
# 15       no
# 16       no
# 17       no
# 18       no
# 19       no
# 20      yes
# 21       no
# 22      yes
# 23       no
# 24       no
# 25       no
# 26      yes
# 27       no
# 28       no
# 29       no
# 30       no
#        ...
# 4090    yes
# 4091     no
# 4092     no
# 4093     no
# 4094     no
# 4095     no
# 4096     no
# 4097     no
# 4098     no
# 4099     no
# 4100     no
# 4101     no
# 4102     no
# 4103     no
# 4104     no
# 4105     no
# 4106     no
# 4107     no
# 4108     no
# 4109     no
# 4110     no
# 4111     no
# 4112     no
# 4113     no
# 4114     no
# 4115     no
# 4116     no
# 4117     no
# 4118     no
# 4119     no
# Name: y, Length: 4113, dtype: object

# %%
BankDataShow['job'].str.lower()
# Out:
# 1         blue-collar
# 2            services
# 3            services
# 4            services
# 5               admin
# 6            services
# 7               admin
# 8        entrepreneur
# 9            services
# 10        blue-collar
# 11           services
# 12      self-employed
# 13              admin
# 14        blue-collar
# 15              admin
# 16           services
# 17              admin
# 18              admin
# 19       entrepreneur
# 20        blue-collar
# 21           services
# 22         technician
# 23         technician
# 24         management
# 25         technician
# 26         technician
# 27         technician
# 28        blue-collar
# 29              admin
# 30              admin
#             ...
# 4090            admin
# 4091      blue-collar
# 4092       management
# 4093      blue-collar
# 4094          retired
# 4095      blue-collar
# 4096            admin
# 4097         services
# 4098      blue-collar
# 4099        housemaid
# ...

# %%
BankDataShow['marital'].str.lower()
# Out:
# 1        married
# 2         single
# 3        married
# 4        married
# 5        married
# 6         single
# 7         single
# 8        married
# 9       divorced
# 10       married
# 11        single
# 12        single
# 13       married
# 14       married
# 15        single
# 16        single
# 17      divorced
# 18      divorced
# 19       married
# 20       married
# 21       married
# 22      divorced
# 23        single
# 24       married
# 25       married
# 26       married
# 27      divorced
# 28       married
# 29        single
# 30       married
#           ...
# 4090      single
# 4091     married
# 4092     married
# 4093      single
# 4094     married
# 4095     married
# 4096      single
# 4097     married
# 4098    divorced
# 4099      single
# 4100    divorced
# 4101    divorced
# 4102      single
# 4103      single
# 4104     married
# 4105    divorced
# 4106     married
# 4107    divorced
# 4108     married
# 4109     married
# 4110     married
# ...

# %%
BankDataShow['education'].str.lower()
# Out:
# 1                  basic.9y
# 2               high.school
# 3               high.school
# 4                  basic.9y
# 5         university.degree
# 6         university.degree
# 7         university.degree
# 8         university.degree
# 9       professional.course
# 10                 basic.9y
# 11                 basic.6y
# 12                 basic.4y
# 13              high.school
# 14                 basic.4y
# 15              high.school
# 16        university.degree
# 17        university.degree
# 18        university.degree
# 19        university.degree
# 20                 basic.4y
# 21                 basic.6y
# 22              high.school
# 23        university.degree
# 24              high.school
# 25      professional.course
# 26      professional.course
# 27      professional.course
# 28                 basic.6y
# 29                  unknown
# 30        university.degree
#                ...
# 4090      university.degree
# 4091               basic.4y
# ...

# %%
BankDataShow['default'].str.lower()
# Out:
# 1            no
# 2            no
# 3            no
# 4            no
# 5            no
# 6            no
# 7            no
# 8       unknown
# 9            no
# 10      unknown
# 11      unknown
# 12           no
# 13           no
# 14           no
# 15           no
# 16           no
# 17           no
# 18           no
# 19      unknown
# 20           no
# 21      unknown
# 22           no
# 23           no
# 24           no
# 25      unknown
# 26           no
# 27           no
# 28      unknown
# 29      unknown
# 30           no
#          ...
# 4090         no
# 4091    unknown
# 4092    unknown
# 4093         no
# 4094    unknown
# 4095         no
# 4096         no
# 4097         no
# 4098         no
# 4099         no
# 4100         no
# 4101         no
# 4102         no
# 4103    unknown
# 4104         no
# 4105         no
# 4106    unknown
# 4107         no
# 4108    unknown
# 4109         no
# 4110         no
# 4111    unknown
# 4112         no
# 4113         no
# ...

# %%
BankDataShow['housing'].str.lower()
# Out:
# 1           yes
# 2            no
# 3           yes
# 4       unknown
# 5           yes
# 6            no
# 7           yes
# 8           yes
# 9            no
# 10           no
# 11          yes
# 12           no
# 13           no
# 14          yes
# 15           no
# 16           no
# 17           no
# 18          yes
# 19          yes
# 20           no
# 21          yes
# 22           no
# 23          yes
# 24           no
# 25          yes
# 26          yes
# 27           no
# 28           no
# 29           no
# 30           no
#          ...
# 4090        yes
# 4091        yes
# 4092         no
# 4093         no
# 4094         no
# 4095        yes
# 4096         no
# 4097         no
# 4098         no
# 4099        yes
# 4100         no
# 4101         no
# 4102        yes
# 4103         no
# 4104         no
# 4105        yes
# 4106        yes
# 4107        yes
# 4108        yes
# 4109        yes
# 4110         no
# 4111    unknown
# 4112         no
# 4113        yes
# ...

# %%
BankDataShow['loan'].str.lower()
# Out:
# 1            no
# 2            no
# 3            no
# 4       unknown
# 5            no
# 6            no
# 7            no
# 8            no
# 9            no
# 10           no
# 11           no
# 12           no
# 13           no
# 14           no
# 15           no
# 16           no
# 17           no
# 18           no
# 19          yes
# 20          yes
# 21           no
# 22           no
# 23          yes
# 24          yes
# 25           no
# 26           no
# 27           no
# 28           no
# 29           no
# 30           no
#          ...
# 4090        yes
# 4091        yes
# 4092         no
# 4093         no
# 4094         no
# 4095         no
# 4096        yes
# 4097         no
# 4098         no
# 4099         no
# 4100         no
# 4101         no
# 4102         no
# 4103        yes
# 4104         no
# 4105         no
# 4106         no
# 4107         no
# 4108         no
# 4109         no
# 4110         no
# 4111    unknown
# 4112        yes
# 4113         no
# ...

# %%
BankDataShow['contact'].str.lower()
# Out:
# 1        cellular
# 2       telephone
# 3       telephone
# 4       telephone
# 5        cellular
# 6        cellular
# 7        cellular
# 8        cellular
# 9        cellular
# 10      telephone
# 11       cellular
# 12       cellular
# 13      telephone
# 14      telephone
# 15       cellular
# 16       cellular
# 17       cellular
# 18      telephone
# 19       cellular
# 20       cellular
# 21       cellular
# 22       cellular
# 23       cellular
# 24       cellular
# 25      telephone
# 26       cellular
# 27      telephone
# 28       cellular
# 29      telephone
# 30       cellular
#           ...
# 4090     cellular
# 4091    telephone
# 4092    telephone
# 4093    telephone
# 4094     cellular
# 4095     cellular
# 4096     cellular
# 4097    telephone
# 4098     cellular
# 4099     cellular
# 4100     cellular
# 4101     cellular
# 4102     cellular
# 4103    telephone
# 4104    telephone
# 4105     cellular
# 4106    telephone
# 4107     cellular
# 4108     cellular
# ...

# %%
BankDataShow['month'].str.lower()
# Out:
# 1       may
# 2       may
# 3       jun
# 4       jun
# 5       nov
# 6       sep
# 7       sep
# 8       nov
# 9       nov
# 10      may
# 11      jul
# 12      jul
# 13      may
# 14      jun
# 15      may
# 16      jul
# 17      jul
# 18      jul
# 19      aug
# 20      jul
# 21      jul
# 22      mar
# 23      aug
# 24      aug
# 25      may
# 26      aug
# 27      may
# 28      may
# 29      may
# 30      aug
#        ...
# 4090    oct
# 4091    may
# 4092    may
# 4093    jul
# 4094    jul
# 4095    nov
# 4096    aug
# 4097    may
# 4098    aug
# 4099    aug
# 4100    aug
# 4101    apr
# 4102    jul
# 4103    jun
# 4104    may
# 4105    aug
# 4106    jul
# 4107    may
# 4108    aug
# 4109    may
# 4110    oct
# 4111    may
# 4112    jun
# 4113    nov
# 4114    nov
# 4115    jul
# 4116    jul
# 4117    may
# 4118    aug
# 4119    nov
# Name: month, Length: 4113, dtype: object

# %%
BankDataShow['day_of_week'].str.lower()
# Out:
# 1       fri
# 2       fri
# 3       wed
# 4       fri
# 5       mon
# 6       thu
# 7       mon
# 8       mon
# 9       tue
# 10      thu
# 11      thu
# 12      thu
# 13      wed
# 14      thu
# 15      fri
# 16      wed
# 17      wed
# 18      mon
# 19      mon
# 20      tue
# 21      tue
# 22      mon
# 23      wed
# 24      wed
# 25      fri
# 26      mon
# 27      wed
# 28      mon
# 29      thu
# 30      tue
#        ...
# 4090    fri
# 4091    tue
# 4092    thu
# 4093    wed
# 4094    tue
# 4095    mon
# 4096    fri
# 4097    mon
# 4098    tue
# 4099    thu
# 4100    tue
# 4101    fri
# 4102    mon
# 4103    fri
# 4104    mon
# 4105    mon
# 4106    tue
# 4107    tue
# 4108    wed
# 4109    thu
# 4110    wed
# 4111    fri
# 4112    fri
# 4113    thu
# 4114    thu
# 4115    thu
# 4116    fri
# 4117    mon
# 4118    fri
# 4119    wed
# Name: day_of_week, Length: 4113, dtype: object

# %%
BankDataShow['poutcome'].str.lower()
# Out:
# 1       nonexistent
# 2       nonexistent
# 3       nonexistent
# 4       nonexistent
# 5       nonexistent
# 6           failure
# 7       nonexistent
# 8       nonexistent
# 9           failure
# 10      nonexistent
# 11      nonexistent
# 12      nonexistent
# 13      nonexistent
# 14      nonexistent
# 15      nonexistent
# 16      nonexistent
# 17      nonexistent
# 18      nonexistent
# 19      nonexistent
# 20      nonexistent
# 21      nonexistent
# 22          success
# 23      nonexistent
# 24      nonexistent
# 25      nonexistent
# 26      nonexistent
# 27      nonexistent
# 28          failure
# 29      nonexistent
# 30      nonexistent
#            ...
# 4090        failure
# 4091    nonexistent
# 4092    nonexistent
# 4093    nonexistent
# 4094    nonexistent
# 4095        success
# 4096    nonexistent
# 4097    nonexistent
# 4098    nonexistent
# 4099    nonexistent
# 4100    nonexistent
# 4101    nonexistent
# 4102    nonexistent
# 4103    nonexistent
# ...

# %%
BankDataShow['y'].str.lower()
# Out:
# 1        no
# 2        no
# 3        no
# 4        no
# 5        no
# 6        no
# 7        no
# 8        no
# 9        no
# 10       no
# 11       no
# 12       no
# 13       no
# 14       no
# 15       no
# 16       no
# 17       no
# 18       no
# 19       no
# 20      yes
# 21       no
# 22      yes
# 23       no
# 24       no
# 25       no
# 26      yes
# 27       no
# 28       no
# 29       no
# 30       no
#        ...
# 4090    yes
# 4091     no
# 4092     no
# 4093     no
# 4094     no
# 4095     no
# 4096     no
# 4097     no
# 4098     no
# 4099     no
# 4100     no
# 4101     no
# 4102     no
# 4103     no
# 4104     no
# 4105     no
# 4106     no
# 4107     no
# 4108     no
# 4109     no
# 4110     no
# 4111     no
# 4112     no
# 4113     no
# 4114     no
# 4115     no
# 4116     no
# 4117     no
# 4118     no
# 4119     no
# Name: y, Length: 4113, dtype: object

# %%
BankDataShow['age'].isnull()==True
# Out:
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
# 30      False
#         ...
# 4090    False
# 4091    False
# 4092    False
# 4093    False
# 4094    False
# 4095    False
# 4096    False
# 4097    False
# 4098    False
# 4099    False
# 4100    False
# 4101    False
# 4102    False
# 4103    False
# 4104    False
# 4105    False
# 4106    False
# 4107    False
# 4108    False
# 4109    False
# 4110    False
# 4111    False
# 4112    False
# 4113    False
# 4114    False
# 4115    False
# 4116    False
# 4117    False
# 4118    False
# 4119    False
# ...

# %%
import numpy as np

# %%
Copy_BankDataShow = BankDataShow.copy()

# %%
Copy_BankDataShow.head(5)
# Out:
#     age          job  marital          education default  housing     loan  \
# 1  30.0  blue-collar  married           basic.9y      no      yes       no
# 2  39.0     services   single        high.school      no       no       no
# 3  25.0     services  married        high.school      no      yes       no
# 4  38.0     services  married           basic.9y      no  unknown  unknown
# 5  47.0        admin  married  university.degree      no      yes       no
#
#      contact month day_of_week ...  campaign  pdays  previous     poutcome  \
# 1   cellular   may         fri ...       2.0  999.0       0.0  nonexistent
# 2  telephone   may         fri ...       4.0  999.0       0.0  nonexistent
# 3  telephone   jun         wed ...       1.0  999.0       0.0  nonexistent
# 4  telephone   jun         fri ...       3.0  999.0       0.0  nonexistent
# 5   cellular   nov         mon ...       1.0  999.0       0.0  nonexistent
#
# ...

# %%
BankDataShow.isnull().any().any()
# Out:
# True

# %%
BankDataShow['age'].fillna(BankDataShow['age'].mean(axis=0), inplace=True)

# %%
BankDataShow['campaign'].fillna(BankDataShow['campaign'].mean(axis=0), inplace=True)

# %%
BankDataShow['pdays'].fillna(BankDataShow['pdays'].mean(axis=0), inplace=True)

# %%
BankDataShow['previous'].fillna(BankDataShow['previous'].mean(axis=0), inplace=True)

# %%
BankDataShow['emp.var.rate'].fillna(BankDataShow['emp.var.rate'].mean(axis=0), inplace=True)

# %%
BankDataShow['cons.price.idx'].fillna(BankDataShow['cons.price.idx'].mean(axis=0), inplace=True)

# %%
BankDataShow['cons.conf.idx'].fillna(BankDataShow['cons.conf.idx'].mean(axis=0), inplace=True)

# %%
BankDataShow['euribor3m'].fillna(BankDataShow['euribor3m'].mean(axis=0), inplace=True)

# %%
BankDataShow['nr.employed'].fillna(BankDataShow['nr.employed'].mean(axis=0), inplace=True)

# %%
import matplotlib.pyplot as plt

# %%
BankDataShow['age'].plot(kind='hist',bins=20)
plt.title('Client Age Data - Portuguese Banking Institution')
labels= ["Age Data"]
plt.legend(labels)
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
BankDataShow['age'].plot(kind='box')
plt.title('Client Age Data - Portuguese Banking Institution')
plt.ylabel('Age Values')
plt.show()

# %%
BankDataShow['job'].value_counts().plot(kind='bar')
plt.title('Different Job Types')
plt.ylabel('Count')
plt.show()

# %%
BankDataShow['job'].value_counts().plot(kind='pie',autopct='%.2f')
plt.title('Different Job Types')
plt.show()

# %%
BankDataShow['marital'].value_counts().plot(kind='pie',autopct='%.2f')
plt.title('Marital Status')
plt.show()

# %%
BankDataShow['marital'].value_counts().plot(kind='bar')
plt.title('Marital Status')
plt.ylabel('Number Count')
plt.show()

# %%
BankDataShow['education'].value_counts().plot(kind='pie',autopct='%.2f')
plt.title('Education Status');
plt.show()

# %%
BankDataShow['education'].value_counts().plot(kind='bar')
plt.title('Education Status')
plt.ylabel('Number Count')
plt.show()

# %%
BankDataShow['default'].value_counts().plot(kind='pie',autopct='%.2f')
plt.title('Number of Defaulters')
plt.show()

# %%
BankDataShow['default'].value_counts().plot(kind='bar')
plt.title('Number of Defaulters')
plt.ylabel('Count')
plt.show()

# %%
BankDataShow['housing'].value_counts().plot(kind='pie',autopct='%.2f')
plt.title('Housing Loan Info')
plt.show()

# %%
BankDataShow['housing'].value_counts().plot(kind='bar')
plt.title('Housing Loan Info')
plt.ylabel('Count')
plt.show()

# %%
BankDataShow['loan'].value_counts().plot(kind='pie',autopct='%.2f')
plt.title('Personal Loan Info')
plt.show()

# %%
BankDataShow['loan'].value_counts().plot(kind='bar')
plt.title('Personal Loan Info')
plt.ylabel('Count')
plt.show()

# %%
BankDataShow['contact'].value_counts().plot(kind='pie',autopct='%.2f')
plt.title('Contact Type Info')
plt.show()

# %%
BankDataShow['contact'].value_counts().plot(kind='bar')
plt.title('Contact Type Info')
plt.ylabel('Count')
plt.show()

# %%
BankDataShow['month'].value_counts().plot(kind='pie',autopct='%.2f')
plt.title('Last Contact Month Info')
plt.show()

# %%
BankDataShow['month'].value_counts().plot(kind='bar')
plt.title('Last Contact Month Info')
plt.ylabel('Count')
plt.show()

# %%
BankDataShow['day_of_week'].value_counts().plot(kind='pie',autopct='%.2f')
plt.title('Last Contact Day Info')
plt.show()

# %%
BankDataShow['day_of_week'].value_counts().plot(kind='bar')
plt.title('Last Contact Day Info')
plt.ylabel('Count')
plt.show()

# %%
BankDataShow['duration'].plot(kind='hist',bins=20)
plt.title('Contact Duration Data')
labels= ["Duration Data"]
plt.legend(labels)
plt.xlabel('Duration')
plt.ylabel('Count')
plt.show()

# %%
BankDataShow['duration'].plot(kind='box')
plt.title('Contact Duration Data')
plt.ylabel('Duration Values')
plt.show()

# %%
BankDataShow['campaign'].plot(kind='hist',bins=20)
plt.title('Contact Campaign Data')
labels= ["campaign Data"]
plt.legend(labels)
plt.xlabel('Campaign')
plt.ylabel('Count')
plt.show()

# %%
BankDataShow['campaign'].plot(kind='box')
plt.title('Contact Campaign Data')
plt.ylabel('Campaign Values')
plt.show()

# %%
BankDataShow['pdays'].plot(kind='hist',bins=20)
plt.title('No of Days passed since last contact')
labels= ["Pdays Data"]
plt.legend(labels)
plt.xlabel('Pdays')
plt.ylabel('Count')
plt.show()

# %%
BankDataShow['previous'].plot(kind='hist',bins=20)
plt.title('No of previous Contacts performed')
labels= ["Previous Data"]
plt.legend(labels)
plt.xlabel('previous attempts')
plt.ylabel('Count')
plt.show()

# %%
BankDataShow['poutcome'].value_counts().plot(kind='pie',autopct='%.2f')
plt.title('Previous Outcome Info')
plt.show()

# %%
BankDataShow['poutcome'].value_counts().plot(kind='bar')
plt.title('Previous Outcome Info')
plt.ylabel('Count')
plt.show()

# %%
BankDataShow['emp.var.rate'].plot(kind='hist',bins=20)
plt.title('Quarterly - Employee Var Rate')
labels= ["Emp Var Rate Data"]
plt.legend(labels)
plt.xlabel('Emp Var Rate')
plt.ylabel('Count')
plt.show()

# %%
BankDataShow['emp.var.rate'].plot(kind='box')
plt.title('Quarterly - Employee Var Rate')
plt.ylabel('Employee Var Rate Count')
plt.show()

# %%
BankDataShow['cons.price.idx'].plot(kind='hist',bins=20)
plt.title('Monthly - Consumer Price Index')
labels= ["Consumer Price Index"]
plt.legend(labels)
plt.xlabel('Consumer Price Index')
plt.ylabel('Count')
plt.show()

# %%
BankDataShow['cons.price.idx'].plot(kind='box')
plt.title('Monthly - Consumer Price Index')
plt.ylabel('Consumer Price Index')
plt.show()

# %%
BankDataShow['cons.conf.idx'].plot(kind='hist',bins=20)
plt.title('Monthly - Consumer Confidence Index')
labels= ["Consumer Confidence Index"]
plt.legend(labels)
plt.xlabel('Consumer Price Index')
plt.ylabel('Count')
plt.show()

# %%
BankDataShow['cons.conf.idx'].plot(kind='box')
plt.title('Monthly - Consumer Confidence Index')
plt.ylabel('Consumer Confidence Index')
plt.show()

# %%
BankDataShow['euribor3m'].plot(kind='hist',bins=20)
plt.title('3 Months Euro Interbank Offered Rate')
labels= ["Euribor Rate"]
plt.legend(labels)
plt.xlabel('Euro Interbank Offered Rate')
plt.ylabel('Count')
plt.show()

# %%
BankDataShow['euribor3m'].plot(kind='box')
plt.title('3 Months Euro Interbank Offered Rate')
plt.ylabel('Count')
plt.show()

# %%
BankDataShow['nr.employed'].plot(kind='hist',bins=20)
plt.title('Number of Employees - Quarterly')
labels= ["No.of Employees"]
plt.legend(labels)
plt.xlabel('Number of Employees')
plt.ylabel('Count')
plt.show()

# %%
BankDataShow['nr.employed'].plot(kind='box')
plt.title('Number of Employees - Quarterly')
plt.ylabel('Count')
plt.show()

# %%
BankDataShow['y'].value_counts().plot(kind='pie',autopct='%.2f')
plt.title('Term Deposit Client Subscription Info')
plt.show()

# %%
BankDataShow['y'].value_counts().plot(kind='bar')
plt.title('Term Deposit Client Subscription Info')
plt.ylabel('Count')
plt.xlabel('Subscription Info')
plt.show()

# %%
plt.scatter(BankDataShow['education'],BankDataShow['campaign'])
plt.title("Scatter plot between Education Level and No of contacts performed during this Campaign")
plt.xlabel("Education Level")
plt.ylabel("No of Contacts Performed")
plt.rcParams['figure.figsize'] = [12,10]
plt.grid(True)
plt.show()

# %%
plt.scatter(BankDataShow['age'],BankDataShow['duration'])
plt.title("Scatter plot between Age of a Person and Duration of calls made")
plt.xlabel("Age in Numbers")
plt.ylabel("Duration of Calls been made in Seconds")
plt.rcParams['figure.figsize'] = [12,10]
plt.grid(True)
plt.show()

# %%
plt.scatter(BankDataShow['nr.employed'],BankDataShow['campaign'])
plt.title("Scatter plot between Number of Employees and Number of contacts performed during this Campaign")
plt.xlabel("Quaterly Strength of Number of Employees")
plt.ylabel("No of contacts Performed During This Campaign")
plt.rcParams['figure.figsize'] = [12,10]
plt.grid(True)
plt.show()

# %%
from pandas.tools.plotting import scatter_matrix
scatter_matrix(BankDataShow,alpha=0.2,figsize=(16,16),diagonal='hist')
plt.show()
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
